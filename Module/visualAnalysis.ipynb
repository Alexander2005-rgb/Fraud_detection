# %% [markdown]
# Visual Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Countplot for Fraud Cases (categorical feature)
plt.figure(figsize=(6,4))
sns.countplot(x='fraud_reported', data=df)
plt.title("Count of Fraud vs Non-Fraud Insurance Claims")
plt.xlabel("Fraud Reported")
plt.ylabel("Count")
plt.show()


# Pie Chart for Incident Severity
incident_counts = df['incident_severity'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(incident_counts, labels=incident_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Composition of Incident Severity")
plt.show()


# Histogram for Age Distribution
plt.figure(figsize=(6,4))
sns.histplot(df['age'], kde=True, bins=20)
plt.title("Age Distribution of Insurance Claims")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Multivariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
corr_matrix = df.corr()

# Plot heatmap to visualize correlation
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")

plt.title("Correlation Heatmap of Features")
plt.show()

# Check highly correlated features
high_corr = corr_matrix["months_as_customer"].sort_values(ascending=False)
print(high_corr)

# %% [markdown]
# Encoding Categorical Features

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# Initialize Label Encoder
le = LabelEncoder()

# Convert categorical columns into numerical values
for column in df.select_dtypes(include=['object']).columns:
    df[column] = le.fit_transform(df[column])

# Separate features (X) and target variable (y)
X = df.drop('fraud_reported', axis=1)   # replace with your target column if different
y = df['fraud_reported']

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,       # 20% data for testing
    random_state=42
)

# Display shapes of the datasets
print("Training Features Shape:", X_train.shape)
print("Testing Features Shape:", X_test.shape)
print("Training Labels Shape:", y_train.shape)
print("Testing Labels Shape:", y_test.shape)

# %% [markdown]
# Scaling

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Initialize Standard Scaler
Std_scaler = StandardScaler()

# Fit and transform training data
X_train = Std_scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train, columns=X.columns)

# Transform testing data
X_test = Std_scaler.transform(X_test)
X_test = pd.DataFrame(X_test, columns=X.columns)
